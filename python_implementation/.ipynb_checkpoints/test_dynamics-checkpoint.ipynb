# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from load_img.baseimage import PETImage, normalize
from scipy.integrate import odeint
from kmeans_segmentation import pca_kmeans_segmentation, fourier_kmeans_segmentation, apply_masks
from utility_functions import sparsifyDynamics, poolData

# %% [markdown]
# #### Some helpful functions

# %%
def disp_segment(seg, view_ax = 'y', col_t = 'sum', col_v = 'sum', figsize=(18, 16)):
    ax_ix = {'z':0,'y':1,'x':2,'t':3}[view_ax]
    
    frame = getattr(seg,col_t)(axis=3)
    
    img = getattr(frame,col_v)(axis=ax_ix)
    
    fig = plt.figure(figsize=figsize)
    plt.imshow(img,cmap='gray')
    plt.show()
    

    
# def find_opt_x0(dynamic_fn, xdf):

# %% [markdown]
# #### Data from File

# %%
data_dir = 'data'
pet_files = [f for f in os.listdir(data_dir) if f.endswith('.pet.img') and not f.startswith('.')]
fname = pet_files[0]
fpath = os.path.join(data_dir,fname)
my_img = PETImage(filepath=fpath)
my_img.load_image()
# Out:
# File dimensions: (128,128,159,40)
# Reading image data...

# %% [markdown]
# ## Segment Image

# %% [markdown]
# #### Fourier Segmentation

# %%
Ns = my_img.img_data.shape

# select the middle z=Ws[0],y=Ws[1],x=Ws[2] prism of each frame
Ws = (128,60,40)
roi_lims = [(int((N-W)/2),int((N+W)/2)) for N,W in zip(Ns,Ws)]

# select options for segmentation and run segmentation
print('Clustering image voxels...')
options = {
    'roi_lims' : roi_lims,
    'plot' : True,
    'fig_size' : (18, 16),
    'nfeatures' : 6,
    'nclusters' : 20
    }
masks, roi = fourier_kmeans_segmentation(my_img,**options)
# Out:
# Clustering image voxels...
# Created 20 masks of image

# %% [markdown]
# #### Time series segmentation

# %%
Ns = my_img.img_data.shape

# select the middle z=Ws[0],y=Ws[1],x=Ws[2] prism of each frame
Ws = (128,60,40)
roi_lims = [(int((N-W)/2),int((N+W)/2)) for N,W in zip(Ns,Ws)]

# select options for segmentation and run segmentation
print('Clustering image voxels...')
options = {
    'roi_lims' : roi_lims,
    'plot' : True,
    'fig_size' : (18, 16),
    'nfeatures' : 6,
    'nclusters' : 20
    }
masks, roi = pca_kmeans_segmentation(my_img,**options)

# done with original image data
my_img.unload_image()
# Out:
# Clustering image voxels...
# Created 20 masks of image

# %% [markdown]
# #### apply masks to original ROI

# %%
# done with original image data
my_img.unload_image()

new_rois = apply_masks(masks,roi)

# %% [markdown]
# #### plot total intensity of each segment

# %%
intensity_curves  = [mroi.reshape(Ws[0]*Ws[1]*Ws[2],Ns[-1]).sum(axis=0) for mroi in new_rois]
df = pd.DataFrame(data=np.stack(intensity_curves).T)
df.plot(figsize=(18, 16),marker='.')

# %%
# subtract mean at each time point from corresponding intensities
sdf = df.subtract(df.mean(axis=1),axis=0)
sdf.plot(figsize=(18, 16),marker='.')

# %% [markdown]
# #### Pick some clusters

# %%
disp_segment(new_rois[3], figsize=(14,12),view_ax='z')
disp_segment(new_rois[6], figsize=(14,12),view_ax='z')
disp_segment(new_rois[14], figsize=(14,12),view_ax='z')

# %% [markdown]
# #### Get cluster data as df

# %%
# since we lose a row in diff step,
# just use first N rows of df


# dont use first few rows with no tracer
N = 40
n_start = 3
npts = N-n_start-1
X = df[n_start:-1]
X_dot = df.diff()[n_start+1:]

# %%
X_dot.shape
# Out:
# (36, 20)

# %% [markdown]
# #### Get subdf with just the ixs of the clusters we want to analyze

# %%
ixs = [3,6,14]
tX = X[ixs].reset_index(drop=True)
tX_dot = X_dot[ixs].reset_index(drop=True)
frame_durations = my_img.params.frame_duration[n_start:-1]
tX_dot = tX_dot.div(frame_durations,axis=0)   # divide out frame duration
tX.shape
# Out:
# (36, 3)

# %% [markdown]
# #### Prepare SINDy

# %%
n,nVars = tX.shape

cols = ['x{}'.format(i+1) for i in range(nVars)]
tX.columns = cols
dot_labels = pd.Index([s + 'dot' for s in cols])

polyorder = 2
lam = 0.001
usesine = 0

Theta = pd.DataFrame()
Theta = poolData(tX,nVars, polyorder, usesine)

# %% [markdown]
# #### Run SINDy

# %%
Xhat_df = sparsifyDynamics(Theta,tX_dot,lam)
Xhat_df = Xhat_df.set_index(dot_labels)
print(Xhat_df.head())
# Out:
#          0   x1        x2   x3  (x1, x1)  (x1, x2)  (x1, x3)  (x2, x2)  \
# x1dot  0.0  0.0  0.000559  0.0  0.008458       0.0       0.0       0.0
# x2dot  0.0  0.0 -0.000000 -0.0  0.001044       0.0       0.0      -0.0
# x3dot  0.0  0.0  0.099908  0.0  0.012833       0.0       0.0       0.0
#
#        (x2, x3)  (x3, x3)
# x1dot       0.0 -0.013073
# x2dot      -0.0 -0.001927
# x3dot       0.0 -0.022917

# %% [markdown]
# ## Test recovered dynamics

# %%
dynamic_fn = lambda x,t: np.squeeze(np.matmul(
        Xhat_df.as_matrix(),
        poolData(pd.DataFrame(x).T,nVars, polyorder, usesine).values.T
))

t_span = np.cumsum(frame_durations)

# how to choose x0?
x0 = tX.iloc[0].values


dynamic_fn(x0,3)
X_s = odeint(dynamic_fn,x0,t_span)

# %% [markdown]
# ###### Plot phase curves for simulated

# %%
xa,xb = 2,1

plt.plot(X_s[:,xa],X_s[:,xb])
tXmat = tX.as_matrix()
plt.plot(tXmat[:,xa],tXmat[:,xb])
plt.legend(['simulated','original'])
plt.show()

# %% [markdown]
# ###### Compare single var over time

# %%
x = 2

fulldf = pd.concat([pd.DataFrame(X_s),tX],axis=1)

plt.plot(t_span,X_s[:,x],'.')
plt.plot(t_span,tXmat[:,x],'.')
plt.legend(['simulated','original'])
plt.show()

# %%
x
# Out:
# array([3.103959  , 1.09238587])

# %%
x = pd.DataFrame(np.array([2,3])).T
np.array(poolData(x,2,2,0))
# Out:
# array([[1., 2., 3., 4., 6., 9.]])

# %%
tX.iloc[0].values
# Out:
# array([19.71612054, 30.63586501])

# %%
def calc_error(x0,dynamic_fn,xdf):
    X_s = odeint(dynamic_fn,x0,t_span)

# %% [markdown]
# #### Show singular values

# %%
X = roi.reshape(128*60*40,40)
U,S,V = np.linalg.svd(X.T.dot(X))
plt.plot(np.arange(40),S,'.')

# %%
poolData(pd.DataFrame(np.array([2,3])).T,nVars, polyorder, usesine).values.T
# Out:
# array([[1.],
#        [2.],
#        [3.],
#        [4.],
#        [6.],
#        [9.]])

# %%
tX_dot.as_matrix()/my_img.params.frame_duration[:-1,np.newaxis]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-4d4b395571c2> in <module>()
# ----> 1 tX_dot/my_img.params.frame_duration[:-1,np.newaxis]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1255     def f(self, other, axis=default_axis, level=None, fill_value=None):
#    1256
# -> 1257         other = _align_method_FRAME(self, other, axis)
#    1258
#    1259         if isinstance(other, ABCDataFrame):  # Another DataFrame
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in _align_method_FRAME(left, right, axis)
#    1178                        "must be {req_shape}: given {given_shape}"
#    1179                        ).format(req_shape=left.shape, given_shape=right.shape)
# -> 1180                 raise ValueError(msg)
#    1181
#    1182             right = left._constructor(right, index=left.index,
#
# ValueError: Unable to coerce to DataFrame, shape must be (39, 2): given (39, 1)

# %%
tX_dot.div(my_img.params.frame_duration[:-1],axis=0)
# Out:
#           10        19
# 1   1.034653  0.364129
# 2   3.629686  2.014547
# 3   2.154414  1.829938
# 4   0.931990  0.639883
# 5   0.572269  0.388935
# 6   1.413963  0.764238
# 7  -1.901540 -0.964908
# 8   0.027860  0.065902
# 9   0.266675  0.220240
# 10  0.268017  0.180710
# 11  0.216901  0.148731
# 12 -0.002560  0.087527
# 13 -0.120634  0.185851
# 14 -0.200441  0.247171
# 15  0.260387  0.454601
# 16 -0.060087  0.071140
# 17  0.079614  0.185203
# 18  0.170120  0.196303
# 19  0.045090  0.102743
# 20  0.028393  0.096457
# 21  0.019022  0.050024
# 22 -0.025022 -0.037249
# 23  0.003331  0.029805
# 24  0.011103  0.025949
# 25  0.000980  0.016493
# 26 -0.001991  0.001804
# 27  0.000306  0.007638
# 28  0.002917  0.008671
# 29 -0.002215  0.001581
# 30 -0.000512  0.001520
# 31 -0.002322 -0.002811
# 32 -0.002060 -0.002629
# 33 -0.001739 -0.003803
# 34 -0.002805 -0.004412
# 35  0.002202  0.001851
# 36 -0.002743 -0.003846
# 37 -0.000997 -0.001736
# 38  0.000258 -0.000388
# 39 -0.001261 -0.001838

# %%
Theta.shape
# Out:
# (39, 6)

# %%
tX.loc[:,'x1']*tX.loc[:,'x2']
# Out:
# 1       3.390721
# 2      53.075592
# 3     128.841451
# 4     166.372105
# 5     191.640713
# 6     253.639479
# 7     174.366435
# 8     181.370955
# 9     215.745496
# 10    249.285840
# 11    278.458412
# 12    287.296389
# 13    297.453075
# 14    306.000055
# 15    373.096455
# 16    374.680176
# 17    428.094831
# 18    507.273602
# 19    541.010425
# 20    570.103935
# 21    586.484493
# 22    571.589121
# 23    594.851524
# 24    621.735574
# 25    634.197375
# 26    633.868556
# 27    645.167491
# 28    662.314001
# 29    659.358945
# 30    661.909738
# 31    623.058524
# 32    588.679765
# 33    550.157615
# 34    501.251684
# 35    529.095901
# 36    485.002663
# 37    467.395454
# 38    466.809064
# dtype: float64

# %%
Theta
# Out:
#       0         x1         x2    (x1, x1)    (x1, x2)    (x2, x2)
# 0   1.0        NaN        NaN         NaN         NaN         NaN
# 1   1.0   3.103959   1.092386    9.634561    3.390721    1.193307
# 2   1.0  10.363330   5.121480  107.398618   53.075592   26.229560
# 3   1.0  14.672159   8.781356  215.272247  128.841451   77.112214
# 4   1.0  16.536139  10.061122  273.443893  166.372105  101.226167
# 5   1.0  17.680677  10.838992  312.606334  191.640713  117.483745
# 6   1.0  20.508603  12.367467  420.602799  253.639479  152.954249
# 7   1.0  16.705524  10.437651  279.074523  174.366435  108.944569
# 8   1.0  16.844822  10.767163  283.748035  181.370955  115.931810
# 9   1.0  18.178198  11.868365  330.446891  215.745496  140.858093
# 10  1.0  19.518282  12.771915  380.963339  249.285840  163.121812
# 11  1.0  20.602787  13.515570  424.474837  278.458412  182.670633
# 12  1.0  20.589989  13.953207  423.947662  287.296389  194.691994
# 13  1.0  19.986818  14.882462  399.472908  297.453075  221.487690
# 14  1.0  18.984615  16.118317  360.415617  306.000055  259.800156
# 15  1.0  20.286549  18.391322  411.544068  373.096455  338.240727
# 16  1.0  19.986116  18.747023  399.444829  374.680176  351.450873
# 17  1.0  20.782256  20.599055  431.902154  428.094831  424.321069
# 18  1.0  22.483454  22.562085  505.505717  507.273602  509.047670
# 19  1.0  22.934359  23.589516  525.984806  541.010425  556.465277
# 20  1.0  23.218289  24.554089  539.088951  570.103935  602.903280
# 21  1.0  23.408505  25.054333  547.958123  586.484493  627.719613
# 22  1.0  23.158283  24.681843  536.306079  571.589121  609.193398
# 23  1.0  23.258208  25.575982  540.944262  594.851524  654.130861
# 24  1.0  23.591289  26.354455  556.548940  621.735574  694.557291
# 25  1.0  23.620689  26.849233  557.936934  634.197375  720.881315
# 26  1.0  23.560949  26.903354  555.118328  633.868556  723.790453
# 27  1.0  23.579295  27.361611  555.983147  645.167491  748.657750
# 28  1.0  23.754305  27.881852  564.266983  662.314001  777.397667
# 29  1.0  23.488516  28.071546  551.710372  659.358945  788.011683
# 30  1.0  23.427117  28.253999  548.829809  661.909738  798.288458
# 31  1.0  22.730496  27.410688  516.675433  623.058524  751.345816
# 32  1.0  22.112484  26.622055  488.961945  588.679765  708.733817
# 33  1.0  21.590795  25.481119  466.162416  550.157615  649.287439
# 34  1.0  20.749389  24.157419  430.537140  501.251684  583.580898
# 35  1.0  21.409936  24.712633  458.385359  529.095901  610.714254
# 36  1.0  20.586945  23.558749  423.822289  485.002663  555.014660
# 37  1.0  20.287980  23.038048  411.602129  467.395454  530.751653
# 38  NaN  20.365494  22.921568  414.753346  466.809064  525.398298

# %%
len(np.ones(38))
# Out:
# 38

# %%
tX.reset_index()
# Out:
#     index         x1         x2
# 0       1   3.103959   1.092386
# 1       2  10.363330   5.121480
# 2       3  14.672159   8.781356
# 3       4  16.536139  10.061122
# 4       5  17.680677  10.838992
# 5       6  20.508603  12.367467
# 6       7  16.705524  10.437651
# 7       8  16.844822  10.767163
# 8       9  18.178198  11.868365
# 9      10  19.518282  12.771915
# 10     11  20.602787  13.515570
# 11     12  20.589989  13.953207
# 12     13  19.986818  14.882462
# 13     14  18.984615  16.118317
# 14     15  20.286549  18.391322
# 15     16  19.986116  18.747023
# 16     17  20.782256  20.599055
# 17     18  22.483454  22.562085
# 18     19  22.934359  23.589516
# 19     20  23.218289  24.554089
# 20     21  23.408505  25.054333
# 21     22  23.158283  24.681843
# 22     23  23.258208  25.575982
# 23     24  23.591289  26.354455
# 24     25  23.620689  26.849233
# 25     26  23.560949  26.903354
# 26     27  23.579295  27.361611
# 27     28  23.754305  27.881852
# 28     29  23.488516  28.071546
# 29     30  23.427117  28.253999
# 30     31  22.730496  27.410688
# 31     32  22.112484  26.622055
# 32     33  21.590795  25.481119
# 33     34  20.749389  24.157419
# 34     35  21.409936  24.712633
# 35     36  20.586945  23.558749
# 36     37  20.287980  23.038048
# 37     38  20.365494  22.921568

# %%
tX.reset_index().reset_index()
# Out:
#     level_0  index  x1         x2         x3
# 0         0      0   1   3.103959   1.092386
# 1         1      1   2  10.363330   5.121480
# 2         2      2   3  14.672159   8.781356
# 3         3      3   4  16.536139  10.061122
# 4         4      4   5  17.680677  10.838992
# 5         5      5   6  20.508603  12.367467
# 6         6      6   7  16.705524  10.437651
# 7         7      7   8  16.844822  10.767163
# 8         8      8   9  18.178198  11.868365
# 9         9      9  10  19.518282  12.771915
# 10       10     10  11  20.602787  13.515570
# 11       11     11  12  20.589989  13.953207
# 12       12     12  13  19.986818  14.882462
# 13       13     13  14  18.984615  16.118317
# 14       14     14  15  20.286549  18.391322
# 15       15     15  16  19.986116  18.747023
# 16       16     16  17  20.782256  20.599055
# 17       17     17  18  22.483454  22.562085
# 18       18     18  19  22.934359  23.589516
# 19       19     19  20  23.218289  24.554089
# 20       20     20  21  23.408505  25.054333
# 21       21     21  22  23.158283  24.681843
# 22       22     22  23  23.258208  25.575982
# 23       23     23  24  23.591289  26.354455
# 24       24     24  25  23.620689  26.849233
# 25       25     25  26  23.560949  26.903354
# 26       26     26  27  23.579295  27.361611
# 27       27     27  28  23.754305  27.881852
# 28       28     28  29  23.488516  28.071546
# 29       29     29  30  23.427117  28.253999
# 30       30     30  31  22.730496  27.410688
# 31       31     31  32  22.112484  26.622055
# 32       32     32  33  21.590795  25.481119
# 33       33     33  34  20.749389  24.157419
# 34       34     34  35  21.409936  24.712633
# 35       35     35  36  20.586945  23.558749
# 36       36     36  37  20.287980  23.038048
# 37       37     37  38  20.365494  22.921568
